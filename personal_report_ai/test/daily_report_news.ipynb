# %%
import requests
import json

# %%
with open("../secrets.json") as f:
    secrets = json.load(f)
    
api_key = secrets['mediastack_api_key']

# %%
class NewsService:
    def __init__(self, api_key):
        self.api_key = api_key
        self.base_url = "http://api.mediastack.com/v1/news"
    def MediaStack_get_news(self, keywords = None, categories = None, countries = None, limit = 10):
        """
        Fetch news articles from MediaStack API
        
        Parameters:
        - keywords: Search term(s)
        - categories: News categories (e.g., business, sports)
        - countries: Countries of news sources (e.g., us, gb)
        - limit: Number of articles to return
        """
        params = {
            'access_key': self.api_key,
            'limit': limit,
        }
        if keywords:
            params['keywords'] = keywords
        if categories:
            params['categorries']= ','.join(categories) if isinstance(categories, list) else categories
        if countries:
            params['countries'] = '.'.join(countries) if isinstance(countries, list) else countries
        response = requests.get(self.base_url, params=params)
        
        if response.status_code == 200:
            return response.json()
        else:
            print(f"Error: {response.status_code}")
            return None

# %%
news = NewsService(api_key)
keywords = 'technology, science'
categories = ''
countries = ''
news.MediaStack_get_news(keywords, categories, countries)
# Out:
# {'pagination': {'limit': 10, 'offset': 0, 'count': 10, 'total': 10000},
#  'data': [{'author': 'GlobeNewswire',
#    'title': 'Abaxx Announces C$20,000,000 Convertible Debenture Offering',
#    'description': 'NOT FOR DISTRIBUTION TO U.S. NEWSWIRE SERVICES OR DISSEMINATION IN THE UNITED STATES TORONTO, March 17, 2025 (GLOBE NEWSWIRE) &#8212; Abaxx Technologies Inc. (CBOE:ABXX)(OTCQX:ABXXF) (“Abaxx” or the “Company”), a financial software and market infrastructure company, indirect majority shareholder of Abaxx Singapore Pte Ltd., the owner of Abaxx Commodity Exchange and Clearinghouse (individually, “Abaxx Exchange” and [&#8230;]',
#    'url': 'https://financialpost.com/globe-newswire/abaxx-announces-c20000000-convertible-debenture-offering',
#    'source': 'business',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'us',
#    'published_at': '2025-03-17T20:37:56+00:00'},
#   {'author': None,
#    'title': 'Through the “Trade and Technology Empowerment for the Earthquake Region” program, Hepsiburada Contributed to a TRY 9.6 Billion Trade Volume in the Region in a Twenty Four Month Period ended March 11, 2025',
#    'description': 'ISTANBUL, March 17, 2025 (GLOBE NEWSWIRE) -- D-MARKET Electronic Services\xa0& Trading (d/b/a “Hepsiburada”) (NASDAQ: HEPS), a leading Turkish e-commerce platform (referred to herein as “Hepsiburada” or the “Company”), announces the 24-month results of the “Trade and Technology Empowerment for th. [mehr]',
#    'url': 'https://www.aktiencheck.de/news/Artikel-Through_the_Trade_and_Technology_Empowerment_for_the_Earthquake_Region_program_Hepsiburada_Contributed_to_a_TRY_9_6_Billion_Trade_Volume_the_Region_a_Twenty_Four_Month_Period_ended_March_11_2025-18315892',
#    'source': 'aktiencheck',
#    'image': None,
#    'category': 'general',
#    'language': 'de',
#    'country': 'de',
#    'published_at': '2025-03-17T20:36:01+00:00'},
#   {'author': None,
#    'title': 'ConnectM Technology requests Nasdaq hearing for continued listing compliance',
#    'description': 'ConnectM Technology requests Nasdaq hearing for continued listing compliance',
#    'url': 'https://seekingalpha.com/news/4421504-connectm-technology-requests-nasdaq-hearing-for-continued-listing-compliance?utm_source=feed_news_all&utm_medium=referral&feed_item_type=news',
#    'source': 'Seeking Alpha',
#    'image': None,
#    'category': 'business',
#    'language': 'en',
#    'country': 'us',
#    'published_at': '2025-03-17T20:25:50+00:00'},
#   {'author': None,
#    'title': 'Intellabridge Technology Corporation Aktie: Bilanzvorlage demnächst',
#    'description': 'Die Intellabridge Technology Corporation verzeichnete am 17. März einen bemerkenswerten Kursanstieg. Die Aktie des Fintech-Unternehmens legte um 27,66% zu und schloss bei 0,03 EUR, was einem Plus von 0,01 EUR gegenüber dem Vortag entspricht. Dieser kurzfristige Aufschwung erfolgt inmitten einer längerfristigen Herausforderung. [mehr]',
#    'url': 'https://www.aktiencheck.de/news/Artikel-Intellabridge_Technology_Corporation_Aktie_Bilanzvorlage_demnaechst-18315824',
#    'source': 'aktiencheck',
#    'image': None,
#    'category': 'general',
#    'language': 'de',
#    'country': 'de',
#    'published_at': '2025-03-17T20:21:22+00:00'},
#   {'author': None,
#    'title': 'Hyperfine, Inc. Reports Fourth Quarter and Full Year 2024 Financial Results',
#    'description': 'GUILFORD, Conn., March 17, 2025 (GLOBE NEWSWIRE) -- Hyperfine, Inc. (Nasdaq: HYPR), the groundbreaking health technology company that has redefined brain imaging with the first FDA-cleared AI-powered portable magnetic resonance (MR) brain imaging system—the Swoop® system—today announced fourth qua. [mehr]',
#    'url': 'https://www.aktiencheck.de/news/Artikel-Hyperfine_Inc_Reports_Fourth_Quarter_and_Full_Year_2024_Financial_Results-18315814',
#    'source': 'aktiencheck',
#    'image': None,
#    'category': 'general',
#    'language': 'de',
#    'country': 'de',
#    'published_at': '2025-03-17T20:20:57+00:00'},
#   {'author': None,
#    'title': 'Large Cap Stocks To Keep An Eye On - March 17th',
#    'description': "NVIDIA, Tesla, Invesco QQQ, Palantir Technologies, and Meta Platforms are the five Large Cap stocks to watch today, according to MarketBeat's stock screener tool. Large cap stocks are shares of companies with sizable market capitalizations, typically exceeding $10 billion, indicating a well-establi",
#    'url': 'https://www.marketbeat.com/instant-alerts/large-cap-stocks-to-keep-an-eye-on-march-17th-2025-03-17/',
#    'source': 'lulegacy',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'us',
#    'published_at': '2025-03-17T20:01:53+00:00'},
#   {'author': None,
#    'title': 'Restaurant Stocks To Research - March 17th',
#    'description': "Alibaba Group, Berkshire Hathaway, Uber Technologies, Booking, and Coca-Cola are the five Restaurant stocks to watch today, according to MarketBeat's stock screener tool. Restaurant stocks are shares in companies that own or operate eating establishments, ranging from fast-food chains to fine dinin",
#    'url': 'https://www.marketbeat.com/instant-alerts/restaurant-stocks-to-research-march-17th-2025-03-17/',
#    'source': 'lulegacy',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'us',
#    'published_at': '2025-03-17T20:01:52+00:00'},
#   {'author': None,
#    'title': 'Virtual Reality Stocks To Consider - March 17th',
#    'description': "Meta Platforms, Best Buy, Unity Software, EPAM Systems, GameStop, Ambarella, and Kopin are the seven Virtual Reality stocks to watch today, according to MarketBeat's stock screener tool. Virtual reality stocks refer to shares in companies that develop, manufacture, or market technology and content",
#    'url': 'https://www.marketbeat.com/instant-alerts/virtual-reality-stocks-to-consider-march-17th-2025-03-17/',
#    'source': 'lulegacy',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'us',
#    'published_at': '2025-03-17T20:01:50+00:00'},
#   {'author': None,
#    'title': 'Promising Space Stocks To Add to Your Watchlist - March 17th',
#    'description': "Alphabet, Berkshire Hathaway, and Boeing are the three Space stocks to watch today, according to MarketBeat's stock screener tool. Space stocks are shares of companies that specialize in space-related industries such as satellite technology, launch services, and space exploration. They represent a",
#    'url': 'https://www.marketbeat.com/instant-alerts/promising-space-stocks-to-add-to-your-watchlist-march-17th-2025-03-17/',
#    'source': 'lulegacy',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'us',
#    'published_at': '2025-03-17T20:01:48+00:00'},
#   {'author': None,
#    'title': 'Technology Stocks To Research - March 17th',
#    'description': "NVIDIA, Meta Platforms, and Apple are the three Technology stocks to watch today, according to MarketBeat's stock screener tool. Technology stocks are shares in companies that produce, innovate, or utilize advanced technological products and services, such as software, hardware, and telecommunicati",
#    'url': 'https://www.marketbeat.com/instant-alerts/technology-stocks-to-research-march-17th-2025-03-17/',
#    'source': 'lulegacy',
#    'image': None,
#    'category': 'general',
#    'language': 'en',
#    'country': 'us',
#    'published_at': '2025-03-17T20:01:48+00:00'}]}
